# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import os
import warnings
import openpyxl
warnings.filterwarnings("ignore")

# %%
sheet = openpyxl.load_workbook('/Users/bestw/Library/CloudStorage/OneDrive-개인/개인_교육_자료/평택시_인구/이전/2016년+1월말+평택시+연령별+인구현황.xlsx').sheetnames

# %%
path = os.chdir('/Users/bestw/Library/CloudStorage/OneDrive-개인/개인_교육_자료/평택시_인구/이전')

# %%
os.listdir(path)
# Out:
# ['2017년+4월말+평택시+연령별+인구현황.xlsx',
#  '2020년+2월말+평택시+연령별+인구현황.xlsx',
#  '1월말^M평택시^M연령별인구현황.xlsx',
#  '2월말평택시연령별현황.xlsx',
#  '2017년+5월말+평택시+연령별+인구현황.xlsx',
#  '2020년+3월말+평택시+연령별+인구현황.xlsx',
#  '2016년+9월말+평택시+연령별+인구현황.xlsx',
#  '2016년+11월말+평택시+연령별+인구현황.xlsx',
#  '2017년+3월말+평택시+연령별+인구현황.xlsx',
#  '2018년도+9월말+평택시+연령별+인구현황.xlsx',
#  '2020년+5월말+평택시+연령별+인구현황.xlsx',
#  '2016년+10월말+평택시+연령별+인구현황.xlsx',
#  '2017년+2월말+평택시+연령별+인구현황.xlsx',
#  '3월말^M평택시^M연령별인구현황.xlsx',
#  '2020년+4월말+평택시+연령별+인구현황.xlsx',
#  '2018년도+8월말+평택시+연령별+인구현황.xlsx',
#  '2016년+8월말+평택시+연령별+인구현황.xlsx',
#  '2017년도+12월말+평택시+연령별+인구현황.xlsx',
#  '2019년도+3월말+평택시+연령별+인구현황.xlsx',
#  '3월말평택시연령별현황.xlsx',
#  '2016년+1월말+평택시+연령별+인구현황.xlsx',
#  '2018년도+1월말+평택시+연령별+인구현황.xlsx',
#  '2019년도+2월말+평택시+연령별+인구현황.xlsx',
#  '2018년도+6월말+평택시+연령별+인구현황.xlsx',
#  '2018년도+12월말+평택시+연령별+인구현황.xlsx',
#  '2016년+6월말+평택시+연령별+인구현황.xlsx',
#  '2019년도+4월말+평택시+연령별+인구현황.xlsx',
#  '2017년도+8월말+평택시+연령별+인구현황.xlsx',
#  '2월말^M평택시^M연령별인구현황.xlsx',
#  '2016년+7월말+평택시+연령별+인구현황.xlsx',
#  '2019년도+5월말+평택시+연령별+인구현황.xlsx',
#  '2017년도+9월말+평택시+연령별+인구현황.xlsx',
#  '2018년도+7월말+평택시+연령별+인구현황.xlsx',
#  '1월말평택시연령별현황.xlsx',
#  '2019년도+12월말+평택시+연령별+인구현황.xlsx',
#  '2017년+6월말+평택시+연령별+인구현황.xlsx',
#  '14_3월말+평택시+연령별인구현황.xlsx',
#  '2017년+7월말+평택시+연령별+인구현황.xlsx',
#  '2020년+1월말+평택시+연령별+인구현황.xlsx',
#  '2020년도+6월말+평택시+연령별+인구현황.xlsx',
#  '2019년도+9월말+평택시+연령별+인구현황.xlsx',
#  '2017년도+11월말+평택시+연령별+인구현황.xlsx',
#  '2017년+1월말+평택시+연령별+인구현황.xlsx',
#  '2016년+12월말+평택시+연령별+인구현황.xlsx',
#  '2020년도+7월말+평택시+연령별+인구현황.xlsx',
#  '2019년도+8월말+평택시+연령별+인구현황.xlsx',
#  '2017년도+10월말+평택시+연령별+인구현황.xlsx',
#  '2019년도+1월말+평택시+연령별+인구현황.xlsx',
#  '2016년+3월말+평택시+연령별+인구현황.xlsx',
#  '2018년도+3월말+평택시+연령별+인구현황.xlsx',
#  '2018년도+2월말+평택시+연령별+인구현황.xlsx',
#  '2016년+2월말+평택시+연령별+인구현황.xlsx',
#  '2018년도+4월말+평택시+연령별+인구현황.xlsx',
#  '2018년도+10월말+평택시+연령별+인구현황.xlsx',
#  '2019년도+11월말+평택시+연령별+인구현황.xlsx',
#  '2016년+4월말+평택시+연령별+인구현황.xlsx',
#  '2019년도+6월말+평택시+연령별+인구현황.xlsx',
#  '2020년도+9월말+평택시+연령별+인구현황.xlsx',
#  '2016년+5월말+평택시+연령별+인구현황.xlsx',
#  '2019년도+7월말+평택시+연령별+인구현황.xlsx',
#  '2020년도+8월말+평택시+연령별+인구현황.xlsx',
#  '2018년도+5월말+평택시+연령별+인구현황.xlsx',
#  '2019년도+10월말+평택시+연령별+인구현황.xlsx',
#  '2018년도+11월말+평택시+연령별+인구현황.xlsx']
